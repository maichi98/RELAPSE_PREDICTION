# %%
from aidream_data.core import AidreamDatabase
from aidream_data import constants

import pandas as pd
import numpy as np

# %%
def sort_name_list(list_patients):

    sorted_list = [list_patients[i] for i in np.argsort([int(p.strip("AIDREAM_")) for p in list_patients])]
    return sorted_list

# %% [markdown]
# # 1 -  Determine the list of AIDREAM perfusion patients :

# %%
# Load the AIDREAM Database : 
aidream_db = AidreamDatabase()
aidream_db.connect()

# %%
# Load the AIDREAM clinical data spreadsheet : 
df_clinical_data = aidream_db.get_clinical_data()
list_patients_per_clinical_data = df_clinical_data['id_aidream'].loc[df_clinical_data["avec_perf"] == "TRUE"].tolist()
list_patients_per_clinical_data = sort_name_list(list_patients_per_clinical_data)

# %%
# Load the AIDREAM cohort info spreadsheet : 
df_cohort_info = aidream_db.get_cohort_info()
list_patients_per_cohort_info = df_cohort_info['patient id']['patient id'].loc[df_cohort_info['']['Perfusion?'] == "oui"].tolist()
list_patients_per_cohort_info = sort_name_list(list_patients_per_cohort_info)

# %%
# AIDREAM perfusion patients in cohort_info but not in clinical_data : 
cohort_info_diff_clinical_data = list(set(list_patients_per_cohort_info) - set(list_patients_per_clinical_data))

df_clinical_data.loc[df_clinical_data['id_aidream'].isin(cohort_info_diff_clinical_data)]
# Out:
#       id_aidream Centre    Cohorte   id_cercare         IPP AIDREAM_ID_300pat  \
# 161  AIDREAM_248    IGR  new400pat  AIDREAM_248  8003022898            300pat
# 209  AIDREAM_303    IGR  new400pat  AIDREAM_303  8014669160       AIDREAM_303
# 242  AIDREAM_334    IGR  new400pat  AIDREAM_334                   AIDREAM_334
# 243  AIDREAM_335    IGR  new400pat  AIDREAM_335                   AIDREAM_335
# 247  AIDREAM_339    IGR  new400pat  AIDREAM_339                   AIDREAM_339
#
#     avec_perf IRM_preRT_ax IRM_rechute_ax                       Reperes_preRT  \
# 161     FALSE        nonAx     à axaliser                         GE_repNATIV
# 209     FALSE   à axaliser     à axaliser  GE_repNativAXIALISEDnew_surAppliGE
# 242     FALSE   à axaliser          nonAx  GE_repNativAXIALISEDnew_surAppliGE
# 243     FALSE   à axaliser          nonAx  GE_repNativAXIALISEDnew_surAppliGE
# 247     FALSE   à axaliser     à axaliser  GE_repNativAXIALISEDnew_surAppliGE
#
#      ... recidive_distance recidive_distance_date recidive_infield_distant  \
# 161  ...                na                     na                       na
# 209  ...                na                     na                       na
# 242  ...                na                     na                       na
# 243  ...                na                     na                       na
# 247  ...                na                     na                       na
#
#         CT_date   Dosi_date IRM__preRT_date IRM__rechute_date  \
# 161    7/6/2018  07/06/2018      13/06/2018        16/01/2019
# 209  12/11/2020  12/11/2020      20/10/2020        20/01/2021
# 242  18/03/2019  18/03/2019      21/02/2019        07/12/2019
# 243  21/03/2019  21/03/2019      22/02/2019        13/05/2020
# 247  06/09/2019  06/09/2019      17/08/2019        08/09/2020
#
#     delai_IRMrechute_IRMpreRT_mois delai_irmrechute_RTj1_jours  \
# 161                              7                         208
# 209                              3                          62
# 242                              9                         256
# 243                             15                         408
# 247                             13                         357
#
#     PTV_volume_total_cm3
# 161                  198
# 209                  337
# 242                  302
# 243                   na
# 247                  564
#
# [5 rows x 136 columns]

# %%
# AIDREAM perfusion patients in clinical_data  but not in cohort_info : 
clinical_data_diff_cohort_info = list(set(list_patients_per_clinical_data) - set(list_patients_per_cohort_info))

df_cohort_info.loc[df_cohort_info['patient id']['patient id'].isin(clinical_data_diff_cohort_info)]
# Out:
#       patient id   id                Center             Cohort             \
#       patient id                         Ce                 Co Perfusion?
# 80   AIDREAM_134  134  exclu;img manquantes   xMMI_PROB_166pat       xoui
# 84   AIDREAM_138  138  exclu;img manquantes   xMMI_PROB_166pat       xoui
# 102  AIDREAM_154  154                   IGR    MMI_PROB_166pat       xoui
# 179  AIDREAM_223  223                   IGR    MMI_PROB_166pat       xoui
# 193  AIDREAM_236  236                   IGR  xxMMI_PROB_166pat       xoui
# 204  AIDREAM_246  246  exclu;img manquantes          xMMI_PROB       xoui
# 663   AIDREAM_66   66                   IGR  xxMMI_PROB_166pat       xoui
#
#     Data at Thera                                                   ...  \
#             CT&MR        Reg? GTV in RTSS CTV in RTSS   RTSS zones  ...
# 80             OK          OK          OK          OK           OK  ...
# 84             OK  NO (exclu)          OK          OK           OK  ...
# 102            OK                      NO          OK  OK - 2 RTSS  ...
# 179            OK          OK          OK          OK  OK - 2 RTSS  ...
# 193            OK          OK          OK          OK  OK - 2 RTSS  ...
# 204            OK          OK          OK          OK           OK  ...
# 663            OK                      NO          OK  OK - 2 RTSS  ...
#
#     Technical characteristics - preRT T1gd                                  \
#                                      Vox_X   Vox_Y Vox_Z PixelBandwidth_mr
# 80                                  0.4688  0.4688     1           139.492
# 84                                    #N/A    #N/A  #N/A              #N/A
# 102                                 0.4688  0.4688     1           139.492
# 179                                 0.5078  0.5078     3           61.0547
# 193                                 0.4688  0.4688     1           139.492
# 204                                 0.5078  0.5078     1           139.492
# 663                                 0.4688  0.4688     1           139.492
#
#                                                                            \
#         Manufacturer_mr      ModelName_mr MagneticField_mr EchoNumbers_mr
# 80   GE MEDICAL SYSTEMS  DISCOVERY MR750w                3              1
# 84                 #N/A              #N/A             #N/A           #N/A
# 102  GE MEDICAL SYSTEMS  DISCOVERY MR750w                3              1
# 179  GE MEDICAL SYSTEMS      SIGNA EXCITE              1.5              1
# 193  GE MEDICAL SYSTEMS  DISCOVERY MR750w                3              1
# 204  GE MEDICAL SYSTEMS  DISCOVERY MR750w                3              1
# 663  GE MEDICAL SYSTEMS  DISCOVERY MR750w                3              1
#
#
#     EchoTime_mr EchoTrainLength_mr
# 80        2.892                  1
# 84         #N/A               #N/A
# 102       2.904                  1
# 179       5.168                  1
# 193       2.904                  1
# 204       2.992                  1
# 663       2.892                  1
#
# [7 rows x 146 columns]

# %%
# if the list of perfusion patients defined per the intersection of cohort_info and clinical_data : 
list_patients = list(set(list_patients_per_clinical_data).intersection(list_patients_per_cohort_info))
list_patients = sort_name_list(list_patients)

print(fr"the Number of Perfusion Patients (per intersection of cohort_info & clinical_data): {len(list_patients)}")
# Out:
# the Number of Perfusion Patients (per intersection of cohort_info & clinical_data): 228

# %%
# if the list of patients defined per cohort_info : 
list_patients = list_patients_per_cohort_info
list_patients = sort_name_list(list_patients)

print(fr"the Number of Perfusion Patients (per cohort_info): {len(list_patients)}")
# Out:
# the Number of Perfusion Patients (per cohort_info): 233

# %%
# Save the perfusion patients list : 
with open("list_patients.txt", 'w') as f:
    f.writelines([f"{p}\n" for p in list_patients])

# %% [markdown]
# # 2. Create the Metadata csv :

# %%
# Load the perfusion patients list : 
with open("list_patients.txt", 'r') as f:
    list_patients = f.readlines()

list_patients = [p.strip('\n') for p in list_patients]

# %%
df_cohort_info = df_cohort_info.loc[df_cohort_info['patient id']['patient id'].isin(list_patients)]

# %%
cols =     [(                  'patient id',                         'patient id'),
            (                      'Cohort',                                 'Co'),
            (                            '',                       'Type surgery'),
            (                 'Multi-tumor',                        'Multifocal?'),
            (                      'pre-RT',                           'Autoseg?'),
            (                      'pre-RT',                             'Label5'),
            (                      'pre-RT',                             'Label3'),
            (                      'pre-RT',                             'Label1'),
            (                      'pre-RT',                             'Label4'),
            (                      'pre-RT',                             'Label2'),
            (                      'pre-RT',                             'Label6'),
            (                      'pre-RT',                             'Label7'),
            (                      'pre-RT',                             'Label8'),
            (                      'pre-RT',                             'Label9'),
            (                      'pre-RT',                            'Label10'),
            (                      'pre-RT',           'Export données corrigées'),
            (                      'pre-RT',                      'Obs2_preRT_CS'),
            (                      'pre-RT',                      'Obs3_preRT_CV'),
            (                     'Relapse',                           'Autoseg?'),
            (                     'Relapse',                             'Label5'),
            (                     'Relapse',                             'Label3'),
            (                     'Relapse',                             'Label1'),
            (                     'Relapse',                             'Label4'),
            (                     'Relapse',                             'Label2'),
            (                     'Relapse',                             'Label6'),
            (                     'Relapse',                             'Label7'),
            (                     'Relapse',                             'Label8'),
            (                     'Relapse',                             'Label9'),
            (                     'Relapse',                            'Label10'),
            (                     'Relapse',                    'OBS2_relapse_CS'),
            (                     'Relapse',                    'OBS3_relapse_CV'),
            (                         'Sex',                                'Sex'),
            (                 'Age at diag',                        'Age at diag'),
            (                   'IDH muted',                          'IDH muted'),
            (            'MGMT methylation',                   'MGMT methylation'),
            (                      'Center',         'Anatomic pathology/surgery'),
            ('RT treatment characteristics',               'RT_dose_prescrite_Gy'),
            ('RT treatment characteristics',                    'RT_nr_fractions'),
            ('RT treatment characteristics',                'RT_dose_fraction_Gy'),
            ('RT treatment characteristics',                 'RT_etalement_jours'),
            ('RT treatment characteristics',                       'RT_Technique'),
           ]

# %%
df_cohort_info = df_cohort_info[cols]

# %%
dict_cols = {(                  'patient id',                         'patient id') :                      "aidream_id",
             (                      'Cohort',                                 'Co') :                          "cohort",
             (                            '',                       'Type surgery') :                    'surgery type',
             (                 'Multi-tumor',                        'Multifocal?') :                    'Multifocal ?',
             (                      'pre-RT',                           'Autoseg?') :                 'pre_RT Autoseg?',
             (                      'pre-RT',                             'Label5') :                   'pre_RT Label5',
             (                      'pre-RT',                             'Label3') :                   'pre_RT Label3',
             (                      'pre-RT',                             'Label1') :                   'pre_RT Label1',
             (                      'pre-RT',                             'Label4') :                   'pre_RT Label4',
             (                      'pre-RT',                             'Label2') :                   'pre_RT Label2',
             (                      'pre-RT',                             'Label6') :                   'pre_RT Label6',
             (                      'pre-RT',                             'Label7') :                   'pre_RT Label7',
             (                      'pre-RT',                             'Label8') :                   'pre_RT Label8',
             (                      'pre-RT',                             'Label9') :                   'pre_RT Label9',
             (                      'pre-RT',                            'Label10') :                  'pre_RT Label10',
             (                      'pre-RT',           'Export données corrigées') : 'pre_RT Export données corrigées',
             (                      'pre-RT',                      'Obs2_preRT_CS') :            'pre_RT Obs2_preRT_CS',
             (                      'pre-RT',                      'Obs3_preRT_CV') :            'pre_RT Obs3_preRt_CV',
             (                     'Relapse',                           'Autoseg?') :                'Rechute Autoseg?',
             (                     'Relapse',                             'Label5') :                  'Rechute Label5',
             (                     'Relapse',                             'Label3') :                  'Rechute Label3',
             (                     'Relapse',                             'Label1') :                  'Rechute Label1',
             (                     'Relapse',                             'Label4') :                  'Rechute Label4',
             (                     'Relapse',                             'Label2') :                  'Rechute Label2',
             (                     'Relapse',                             'Label6') :                  'Rechute Label6',
             (                     'Relapse',                             'Label7') :                  'Rechute Label7',
             (                     'Relapse',                             'Label8') :                  'Rechute Label8',
             (                     'Relapse',                             'Label9') :                  'Rechute Label9',
             (                     'Relapse',                            'Label10') :                 'Rechute Label10',
             (                     'Relapse',                    'OBS2_relapse_CS') :         'Rechute Obs2_relapse_CS',
             (                     'Relapse',                    'OBS3_relapse_CV') :         'Rechute Obs3_relapse_CV',
             (                         'Sex',                                'Sex') :                             'Sex',
             (                 'Age at diag',                        'Age at diag') :                     'Age at diag',
             (                   'IDH muted',                          'IDH muted') :                       'IDH muted',
             (            'MGMT methylation',                   'MGMT methylation') :                'MGMT methylation',
             (                      'Center',         'Anatomic pathology/surgery') :      'Anatomic pathology/surgery',
             ('RT treatment characteristics',               'RT_dose_prescrite_Gy') :            'RT_dose_prescrite_Gy',
             ('RT treatment characteristics',                    'RT_nr_fractions') :                 'RT_nr_fractions',
             ('RT treatment characteristics',                'RT_dose_fraction_Gy') :             'RT_dose_fraction_Gy',
             ('RT treatment characteristics',                 'RT_etalement_jours') :              'RT_etalement_jours',
             ('RT treatment characteristics',                       'RT_Technique') :                    'RT_Technique'
            }

# %%
df_cohort_info = df_cohort_info.reset_index(drop=True)

df_cohort_info_new = pd.DataFrame(columns=dict_cols.values())

# %%
for col, new_col in dict_cols.items():

    df_cohort_info_new[new_col] = df_cohort_info[col]

# %%
df_cohort_info_new.to_csv("cohort_info_perfusion.csv", index=False)

# %%
df_clinical_data = df_clinical_data.loc[df_clinical_data['id_aidream'].isin(list_patients)].reset_index(drop=True)

# %%
cols = ['id_aidream', 'id_cercare', 'IRM_preRT_ax', 'IRM_rechute_ax', 'deces', 'TYPE_CHIR(Bx=0_STR=1_GTR=2)', 'delai_irmrechute_RTj1_jours', 'PTV_volume_total_cm3']

# %%
df_clinical_data_new = df_clinical_data[cols]

# %%
df_cohort_info_new.to_csv("clinical_data_perfusion.csv", index=False)

# %%
df_cohort_info_new.rename(columns={"aidream_id": "id_aidream"}, inplace=True)

# %%
df_metadata = df_cohort_info_new.merge(df_clinical_data_new, 
                                       on="id_aidream",
                                       how="left")

df_metadata.to_csv("metadata_perfusion.csv", index=False)

# %%
# Load the interim perfusion patients list : 
with open("list_intermediary_patients.txt", 'r') as f:
    list_patients_interim = f.readlines()

list_patients_interim = [p.strip('\n') for p in list_patients_interim]

# %%
df_metadata = df_metadata.loc[df_metadata["id_aidream"].isin(list_patients_interim)].reset_index(drop=True)

# %%
df_metadata.to_csv(fr"metadata_perfusion_interim.csv", index=False)

# %%
df_clinical_data_new.columns
# Out:
# Index(['id_aidream', 'id_cercare', 'IRM_preRT_ax', 'IRM_rechute_ax', 'deces',
#        'TYPE_CHIR(Bx=0_STR=1_GTR=2)', 'delai_irmrechute_RTj1_jours',
#        'PTV_volume_total_cm3'],
#       dtype='object')

# %% [markdown]
# # 3 - Univariate analysis :

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_metadata = pd.read_csv("metadata_perfusion.csv")
df_metadata_interim = pd.read_csv("metadata_perfusion_interim.csv")

# %%
df_metadata.columns
# Out:
# Index(['id_aidream', 'cohort', 'surgery type', 'Multifocal ?',
#        'pre_RT Autoseg?', 'pre_RT Label5', 'pre_RT Label3', 'pre_RT Label1',
#        'pre_RT Label4', 'pre_RT Label2', 'pre_RT Label6', 'pre_RT Label7',
#        'pre_RT Label8', 'pre_RT Label9', 'pre_RT Label10',
#        'pre_RT Export données corrigées', 'pre_RT Obs2_preRT_CS',
#        'pre_RT Obs3_preRt_CV', 'Rechute Autoseg?', 'Rechute Label5',
#        'Rechute Label3', 'Rechute Label1', 'Rechute Label4', 'Rechute Label2',
#        'Rechute Label6', 'Rechute Label7', 'Rechute Label8', 'Rechute Label9',
#        'Rechute Label10', 'Rechute Obs2_relapse_CS', 'Rechute Obs3_relapse_CV',
#        'Sex', 'Age at diag', 'IDH muted', 'MGMT methylation',
#        'Anatomic pathology/surgery', 'RT_dose_prescrite_Gy', 'RT_nr_fractions',
#        'RT_dose_fraction_Gy', 'RT_etalement_jours', 'RT_Technique',
#        'id_cercare', 'IRM_preRT_ax', 'IRM_rechute_ax', 'deces',
#        'TYPE_CHIR(Bx=0_STR=1_GTR=2)', 'delai_irmrechute_RTj1_jours',
#        'PTV_volume_total_cm3'],
#       dtype='object')

# %%
df_clinical_data.columns
# Out:
# Index(['id_aidream', 'Centre', 'Cohorte', 'id_cercare', 'IPP',
#        'AIDREAM_ID_300pat', 'avec_perf', 'IRM_preRT_ax', 'IRM_rechute_ax',
#        'Reperes_preRT',
#        ...
#        'recidive_distance', 'recidive_distance_date',
#        'recidive_infield_distant', 'CT_date', 'Dosi_date', 'IRM__preRT_date',
#        'IRM__rechute_date', 'delai_IRMrechute_IRMpreRT_mois',
#        'delai_irmrechute_RTj1_jours', 'PTV_volume_total_cm3'],
#       dtype='object', length=136)

# %%
for col in df_cohort_info.columns:
    print(col)
# Out:
# ('patient id', 'patient id')
# ('id', '')
# ('Center', 'Ce')
# ('Cohort', 'Co')
# ('', 'Perfusion?')
# ('Data at Thera', 'CT&MR')
# ('Data at Thera', 'Reg?')
# ('Data at Thera', 'GTV in RTSS')
# ('Data at Thera', 'CTV in RTSS')
# ('', 'RTSS zones')
# ('', 'Used AI')
# ('Statuts Surgery', 'Surgery?')
# ('', 'Type surgery')
# ('', 'Date surgery')
# ('', 'Residual disease?')
# ('Multi-tumor', 'Multifocal?')
# ('Multi-tumor', '#tumor')
# ('pre-RT', 'Autoseg?')
# ('pre-RT', 'Batch autoseg')
# ('pre-RT', 'On TPS?')
# ('pre-RT', 'Label5')
# ('pre-RT', 'Label3')
# ('pre-RT', 'Label1')
# ('pre-RT', 'Label4')
# ('pre-RT', 'Label2')
# ('pre-RT', 'Label6')
# ('pre-RT', 'Label7')
# ('pre-RT', 'Label8')
# ('pre-RT', 'Label9')
# ('pre-RT', 'Label10')
# ('pre-RT', 'Vérifié par Sophie')
# ('pre-RT', 'Export données corrigées')
# ('pre-RT', 'Contourer')
# ('pre-RT', 'Time Manual')
# ('pre-RT', 'Time GE')
# ('pre-RT', 'Issues')
# ('pre-RT', 'CAMI_JADE_verification-radiologue')
# ('pre-RT', 'Possible for 1st DL Thera')
# ('pre-RT', 'Possible for CERCARE')
# ('pre-RT', 'Obs2_preRT_CS')
# ('pre-RT', 'Obs3_preRT_CV')
# ('pre-RT', 'NB labels remplis')
# ('pre-RT', 'Sophie')
# ('pre-RT', '*Cédric*')
# ('pre-RT', '*Camilla*')
# ('pre-RT', '*Linda*')
# ('pre-RT', '*Taha*')
# ('Relapse', 'Autoseg?')
# ('Relapse', 'On TPS?')
# ('Relapse', 'Label5')
# ('Relapse', 'Label3')
# ('Relapse', 'Label1')
# ('Relapse', 'Label4')
# ('Relapse', 'Label2')
# ('Relapse', 'Label6')
# ('Relapse', 'Label7')
# ('Relapse', 'Label8')
# ('Relapse', 'Label9')
# ('Relapse', 'Label10')
# ('Relapse', 'Issues')
# ('Relapse', 'Treatments-after-relapse')
# ('Relapse', 'CAMI_JADE_verification-radiologue')
# ('Relapse', 'Possible for 1st DL Thera')
# ('Relapse', 'Possible for CERCARE')
# ('Relapse', 'OBS1_relapse')
# ('Relapse', 'OBS2_relapse_CS')
# ('Relapse', 'OBS3_relapse_CV')
# ('', 'NB labels remplis')
# ('', 'Sophie')
# ('', '*Cédric*')
# ('', '*Camilla*')
# ('', '*Linda*')
# ('', '*Taha*')
# ('General comment', '')
# ('RTSS preRT to TPC?', 'RTSS preRT to TPC?')
# ('RTSS relapse to TPC?', 'RTSS relapse to TPC?')
# ('', '')
# ('Age at diag', 'Age at diag')
# ('Sex', 'Sex')
# ('IDH muted', 'IDH muted')
# ('MGMT methylation', 'MGMT methylation')
# ('Center', 'Anatomic pathology/surgery')
# ('RT treatment characteristics', 'RT_dose_prescrite_Gy')
# ('RT treatment characteristics', 'RT_nr_fractions')
# ('RT treatment characteristics', 'RT_dose_fraction_Gy')
# ('RT treatment characteristics', 'RT_etalement_jours')
# ('RT treatment characteristics', 'RT_Technique')
# ('', '')
# ('Technical characteristics - preRT FLAIR (tags)', 'SeriesDescription_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'StudyDate_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'Rows_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'Columns_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'Vox_X')
# ('Technical characteristics - preRT FLAIR (tags)', 'Vox_Y')
# ('Technical characteristics - preRT FLAIR (tags)', 'Vox_Z')
# ('Technical characteristics - preRT FLAIR (tags)', 'PixelBandwidth_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'Manufacturer_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'ModelName_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'MagneticField_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'EchoNumbers_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'EchoTime_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'EchoTrainLength_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'InversionTime_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'RepetitionTime_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'FlipAngle_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'ReconstructionDiameter_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'ImageOrientationPatient_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'ImagePositionPatient_mr')
# ('Technical characteristics - preRT FLAIR (tags)', 'study_uid')
# ('Technical characteristics - preRT FLAIR (tags)', 'series_uid')
# ('Technical characteristics - preRT T1', 'SeriesDescription_mr')
# ('Technical characteristics - preRT T1', 'StudyDate_mr')
# ('Technical characteristics - preRT T1', 'Rows_mr')
# ('Technical characteristics - preRT T1', 'Columns_mr')
# ('Technical characteristics - preRT T1', 'Vox_X')
# ('Technical characteristics - preRT T1', 'Vox_Y')
# ('Technical characteristics - preRT T1', 'Vox_Z')
# ('Technical characteristics - preRT T1', 'PixelBandwidth_mr')
# ('Technical characteristics - preRT T1', 'Manufacturer_mr')
# ('Technical characteristics - preRT T1', 'ModelName_mr')
# ('Technical characteristics - preRT T1', 'MagneticField_mr')
# ('Technical characteristics - preRT T1', 'EchoNumbers_mr')
# ('Technical characteristics - preRT T1', 'EchoTime_mr')
# ('Technical characteristics - preRT T1', 'EchoTrainLength_mr')
# ('Technical characteristics - preRT T1', 'InversionTime_mr')
# ('Technical characteristics - preRT T1', 'RepetitionTime_mr')
# ('Technical characteristics - preRT T1', 'FlipAngle_mr')
# ('Technical characteristics - preRT T1', 'ReconstructionDiameter_mr')
# ('Technical characteristics - preRT T1', 'ImageOrientationPatient_mr')
# ('Technical characteristics - preRT T1', 'ImagePositionPatient_mr')
# ('Technical characteristics - preRT T1', 'study_uid')
# ('Technical characteristics - preRT T1', 'series_uid')
# ('Technical characteristics - preRT T1gd', 'SeriesDescription_mr')
# ('Technical characteristics - preRT T1gd', 'StudyDate_mr')
# ('Technical characteristics - preRT T1gd', 'Rows_mr')
# ('Technical characteristics - preRT T1gd', 'Columns_mr')
# ('Technical characteristics - preRT T1gd', 'Vox_X')
# ('Technical characteristics - preRT T1gd', 'Vox_Y')
# ('Technical characteristics - preRT T1gd', 'Vox_Z')
# ('Technical characteristics - preRT T1gd', 'PixelBandwidth_mr')
# ('Technical characteristics - preRT T1gd', 'Manufacturer_mr')
# ('Technical characteristics - preRT T1gd', 'ModelName_mr')
# ('Technical characteristics - preRT T1gd', 'MagneticField_mr')
# ('Technical characteristics - preRT T1gd', 'EchoNumbers_mr')
# ('Technical characteristics - preRT T1gd', 'EchoTime_mr')
# ('Technical characteristics - preRT T1gd', 'EchoTrainLength_mr')

# %%
df_clinical_data['tmz_conco'].unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df_clinical_data.loc[df_clinical_data['recidive_diametre_max_mm'] == 'na']
# Out:
#       id_aidream Centre   Cohorte    id_cercare IPP AIDREAM_ID_300pat  \
# 0      AIDREAM_1    IGR  MIM_PROB  MMI-PROB_140                300pat
# 1     AIDREAM_10    IGR  MIM_PROB  MMI-PROB_050                300pat
# 2    AIDREAM_100    IGR  MIM_PROB  MMI-PROB_139                300pat
# 3    AIDREAM_101    IGR  MIM_PROB  MMI-PROB_130                300pat
# 4    AIDREAM_102    IGR  MIM_PROB  MMI-PROB_085           AIDREAM_102
# ..           ...    ...       ...           ...  ..               ...
# 228   AIDREAM_94    IGR  MIM_PROB  MMI-PROB_207                300pat
# 229   AIDREAM_96    IGR  MIM_PROB  MMI-PROB_024                300pat
# 230   AIDREAM_97    IGR  MIM_PROB  MMI-PROB_133                300pat
# 231   AIDREAM_98    IGR  MIM_PROB  MMI-PROB_201            AIDREAM_98
# 232   AIDREAM_99    IGR  MIM_PROB  MMI-PROB_150            AIDREAM_99
#
#     avec_perf IRM_preRT_ax IRM_rechute_ax Reperes_preRT  ...  \
# 0        TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 1        TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 2        TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 3        TRUE   à axaliser     à axaliser   AC_repATLAS  ...
# 4        TRUE        nonAx     à axaliser   AC_repATLAS  ...
# ..        ...          ...            ...           ...  ...
# 228      TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 229      TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 230      TRUE        nonAx     à axaliser   AC_repATLAS  ...
# 231      TRUE   à axaliser     à axaliser   AC_repATLAS  ...
# 232      TRUE        nonAx     à axaliser   AC_repATLAS  ...
#
#     recidive_distance recidive_distance_date recidive_infield_distant  \
# 0                  na                     na                       na
# 1                   0                     na                       na
# 2                   0                     na                       na
# 3                   1                     na                       na
# 4                   0                     na                       na
# ..                ...                    ...                      ...
# 228                na                     na                       na
# 229                na                     na                       na
# 230                na                     na                       na
# 231                na                     na                       na
# 232                na                     na                       na
#
#         CT_date   Dosi_date IRM__preRT_date IRM__rechute_date  \
# 0    23/08/2012  23/08/2012      22/08/2012        07/08/2013
# 1    18/02/2010  18/02/2010      26/02/2010        18/03/2011
# 2    03/08/2012  03/08/2012      03/08/2012        08/04/2013
# 3    05/07/2012  05/07/2012      11/07/2012        05/06/2014
# 4    24/02/2011  24/02/2011      01/03/2011        08/08/2011
# ..          ...         ...             ...               ...
# 228  22/01/2015  22/01/2015      16/01/2015        05/06/2015
# 229  20/05/2009  20/05/2009      19/05/2009        27/05/2013
# 230  31/05/2012  31/05/2012      31/05/2012        15/03/2014
# 231  28/08/2014  28/08/2014      29/08/2014        29/04/2015
# 232  21/02/2013  21/02/2013      22/02/2013        03/10/2014
#
#     delai_IRMrechute_IRMpreRT_mois delai_irmrechute_RTj1_jours  \
# 0                               11                         339
# 1                               13                         374
# 2                                8                         247
# 3                               23                         612
# 4                                5                         159
# ..                             ...                         ...
# 228                              5                         131
# 229                             48                       1 457
# 230                             21                         647
# 231                              8                         232
# 232                             19                         575
#
#     PTV_volume_total_cm3
# 0                    204
# 1                    208
# 2                    128
# 3                    201
# 4                    367
# ..                   ...
# 228                  202
# 229                  191
# 230                  495
# 231                  123
# 232                   95
#
# [226 rows x 136 columns]
